# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynalovvelmar/hello-world/blob/master/AI_kollek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1
num = str(123)
print(num, type(num))

# 2
print(int(19.99))

# 3
print(int("500") / 2)

# 4
a, b = 8, 12
print(a < b, a == b)

# 5
x, y, z = 5, 10, 15
print((x < y) and (y < z))

# 6
print(25 // 4, 25 % 4, 25 / 4)

# 7
print(3 ** 4)

# 8
qiymet = 75.5
qiymet = int(qiymet)
print(qiymet, type(qiymet))

# 9
n = 20
print((n > 10) or (n < 5), (n > 15) and (n < 25))

# 10
val = float("42.8")
print(type(val))
val = int(val)
print(type(val))
# Out:
# 123 <class 'str'>
# 19
# 250.0
# True False
# True
# 6 1 6.25
# 81
# 75 <class 'int'>
# True True
# <class 'float'>
# <class 'int'>

# %%
# 1
s = "Programming"
print(len(s), s[0])

# 2
s1, s2 = "Hello", "World"
print(s1 + " " + s2)

# 3
text = "Python"
print(text[-1])

# 4
s = "Artificial"
print(s[3:])

# 5
word = "Code"
print(word[::-1])

# 6
s = "abcdefgh"
print(s[::2])

# 7
text = "data"
print(text.upper(), text.lower())

# 8
s = "Python-R-Java"
print(s.split("-"))

# 9
ad, yaş = "Ayxan", 25
print(f"{ad} {yaş} yaşındadır")

# 10
s = "salam-dunya"
print(s.replace("-", " "))
# Out:
# 11 P
# Hello World
# n
# ificial
# edoC
# aceg
# DATA data
# ['Python', 'R', 'Java']
# Ayxan 25 yaşındadır
# salam dunya

# %%
# 1
rəqəmlər = [5, 10, 15, 20]

# 2
print(len(rəqəmlər))

# 3
rəqəmlər.append(25)
print(rəqəmlər)

# 4
rəqəmlər.insert(2, 12)
print(rəqəmlər)

# 5
print([1, 2, 3] + [4, 5, 6])

# 6
print(rəqəmlər[2:4])

# 7
rəqəmlər[0] = 50
print(rəqəmlər)

# 8
print(19 in rəqəmlər)

# 9
lst = ["a", "b", "a", "c"]
print(lst.count("a"))

# 10
lst = ["x", "y", "x", "z"]
lst = [i for i in lst if i != "x"]
print(lst)

# 11
nums = [7, 2, 9, 1]
nums.sort(reverse=True)
print(nums)

# 12
print([i for i in rəqəmlər if i > 10])
# Out:
# 4
# [5, 10, 15, 20, 25]
# [5, 10, 12, 15, 20, 25]
# [1, 2, 3, 4, 5, 6]
# [12, 15]
# [50, 10, 12, 15, 20, 25]
# False
# 2
# ['y', 'z']
# [9, 7, 2, 1]
# [50, 12, 15, 20, 25]

# %%
import pandas as pd

# 1
s1 = pd.Series([10, 20, 30, 40])

# 2
s1.index = ['w', 'x', 'y', 'z']
print(s1)

# 3
s2 = pd.Series({'p': 5, 'q': 10, 'r': 15})
print(s2)

# 4
print(s2['q'])

# 5
print(s1[s1 > 25])

# 6
print(s1[s1 > 20] / 10)

# 7
df1 = pd.DataFrame(((1, 2), (3, 4)))

# 8
df1.index = ['r1', 'r2']
df1.columns = ['c1', 'c2']
print(df1)

# 9
df2 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
print(df2)

# 10
print(df2[df2['A'] > 1])
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64
# p     5
# q    10
# r    15
# dtype: int64
# 10
# y    30
# z    40
# dtype: int64
# y    3.0
# z    4.0
# dtype: float64
#     c1  c2
# r1   1   2
# r2   3   4
#    A  B
# 0  1  3
# 1  2  4
#    A  B
# 1  2  4
